# %%
# Imports
import pandas as pd
import re
# For metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, average_precision_score
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
from openai import OpenAI

# %%
# gpt 3.5 turbo

# %%
df = pd.read_excel('9000_0_1_gpt_4o_11.xlsx')
df = df[['Sentiment_ex', 'Sentiment_GPT-3_5_turbo']]

# %%
true_res = df['Sentiment_ex']
predicted =df['Sentiment_GPT-3_5_turbo']
print(classification_report(true_res, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      8221
#            1       0.67      0.95      0.78      1269
#
#     accuracy                           0.93      9490
#    macro avg       0.83      0.94      0.87      9490
# weighted avg       0.95      0.93      0.94      9490

# %%
#this function prints and plot the confusion matrix
import numpy as np
import itertools
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
y_test = true_res
y_pred = predicted
cm = confusion_matrix(y_test,y_pred)
cm

def plot_confusion_matrix(cm,classes,normalize=False,title='Confusion Matrix',cmap=plt.cm.Blues):
  plt.imshow(cm,interpolation='nearest',cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks,classes,rotation=45)
  plt.yticks(tick_marks,classes)

  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalize Confusion Matrix")
  else:
    print('Confusion matrix, without Normalization')
  thresh = cm.max() / 2.
  for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
    plt.text(j,i,cm[i,j],horizontalalignment = "center", color = "white" if cm[i,j] > thresh else "black")
  plt.tight_layout()
  plt.ylabel('True values')
  plt.xlabel('Predicted values')

plot_confusion_matrix(cm,classes = ['Positive','Negative'])
# Out:
# Confusion matrix, without Normalization

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

precision, recall, _ = precision_recall_curve(y_test, y_pred)
pr_auc = average_precision_score(y_test, y_pred)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plotting ROC Curve
ax1.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.4f)' % roc_auc)
ax1.fill_between(fpr, tpr, alpha=0.2, color='blue')
ax1.plot([0, 1], [0, 1], 'k--')
ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.05])
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('AUC & ROC Curve')
ax1.legend(loc="lower right")

# Plotting Precision-Recall Curve
ax2.plot(recall, precision, color='purple', label='PR curve (area = %0.4f)' % pr_auc)
ax2.fill_between(recall, precision, alpha=0.2, color='purple')
ax2.set_xlim([0.0, 1.0])
ax2.set_ylim([0.0, 1.05])
ax2.set_xlabel('Recall')
ax2.set_ylabel('Precision')
ax2.set_title('Precision-Recall Curve')
ax2.legend(loc="lower left")

plt.tight_layout()
plt.show()

# %%
# gpt 4 turbo

# %%
df = pd.read_excel('9000_0_1_gpt_4o_11.xlsx')
df = df[['Sentiment_ex', 'Sentiment_GPT-4-turbo']]

# %%
true_res = df['Sentiment_ex']
predicted =df['Sentiment_GPT-4-turbo']
print(classification_report(true_res, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      8221
#            1       0.77      0.86      0.81      1269
#
#     accuracy                           0.95      9490
#    macro avg       0.87      0.91      0.89      9490
# weighted avg       0.95      0.95      0.95      9490

# %%
#this function prints and plot the confusion matrix
import numpy as np
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
y_test = true_res
y_pred = predicted
cm = confusion_matrix(y_test,y_pred)
cm
def plot_confusion_matrix(cm,classes,normalize=False,title='Confusion Matrix',cmap=plt.cm.Blues):
  plt.imshow(cm,interpolation='nearest',cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks,classes,rotation=45)
  plt.yticks(tick_marks,classes)

  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalize Confusion Matrix")
  else:
    print('Confusion matrix, without Normalization')
  thresh = cm.max() / 2.
  for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
    plt.text(j,i,cm[i,j],horizontalalignment = "center", color = "white" if cm[i,j] > thresh else "black")
  plt.tight_layout()
  plt.ylabel('True values')
  plt.xlabel('Predicted values')

plot_confusion_matrix(cm,classes = ['Positive','Negative'])
# Out:
# Confusion matrix, without Normalization

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
precision, recall, _ = precision_recall_curve(y_test, y_pred)
pr_auc = average_precision_score(y_test, y_pred)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plotting ROC Curve
ax1.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.4f)' % roc_auc)
ax1.fill_between(fpr, tpr, alpha=0.2, color='blue')
ax1.plot([0, 1], [0, 1], 'k--')
ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.05])
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('AUC & ROC Curve')
ax1.legend(loc="lower right")

# Plotting Precision-Recall Curve
ax2.plot(recall, precision, color='purple', label='PR curve (area = %0.4f)' % pr_auc)
ax2.fill_between(recall, precision, alpha=0.2, color='purple')
ax2.set_xlim([0.0, 1.0])
ax2.set_ylim([0.0, 1.05])
ax2.set_xlabel('Recall')
ax2.set_ylabel('Precision')
ax2.set_title('Precision-Recall Curve')
ax2.legend(loc="lower left")

plt.tight_layout()
plt.show()

# %%
#GPT 4o

# %%
df = pd.read_excel('9000_0_1_gpt_4o_11.xlsx')
df = df[['Sentiment_ex', 'Sentiment_GPT-4o']]

# %%
true_res = df['Sentiment_ex']
predicted =df['Sentiment_GPT-4o']
print(classification_report(true_res, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      8221
#            1       0.98      0.69      0.81      1269
#
#     accuracy                           0.96      9490
#    macro avg       0.97      0.84      0.89      9490
# weighted avg       0.96      0.96      0.95      9490

# %%
#this function prints and plot the confusion matrix
import numpy as np
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
y_test = true_res
y_pred = predicted
cm = confusion_matrix(y_test,y_pred)
cm
def plot_confusion_matrix(cm,classes,normalize=False,title='Confusion Matrix',cmap=plt.cm.Blues):
  plt.imshow(cm,interpolation='nearest',cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks,classes,rotation=45)
  plt.yticks(tick_marks,classes)

  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalize Confusion Matrix")
  else:
    print('Confusion matrix, without Normalization')
  thresh = cm.max() / 2.
  for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
    plt.text(j,i,cm[i,j],horizontalalignment = "center", color = "white" if cm[i,j] > thresh else "black")
  plt.tight_layout()
  plt.ylabel('True values')
  plt.xlabel('Predicted values')

plot_confusion_matrix(cm,classes = ['Positive','Negative'])
# Out:
# Confusion matrix, without Normalization

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
precision, recall, _ = precision_recall_curve(y_test, y_pred)
pr_auc = average_precision_score(y_test, y_pred)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plotting ROC Curve
ax1.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.4f)' % roc_auc)
ax1.fill_between(fpr, tpr, alpha=0.2, color='blue')
ax1.plot([0, 1], [0, 1], 'k--')
ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.05])
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('AUC & ROC Curve')
ax1.legend(loc="lower right")

# Plotting Precision-Recall Curve
ax2.plot(recall, precision, color='purple', label='PR curve (area = %0.4f)' % pr_auc)
ax2.fill_between(recall, precision, alpha=0.2, color='purple')
ax2.set_xlim([0.0, 1.0])
ax2.set_ylim([0.0, 1.05])
ax2.set_xlabel('Recall')
ax2.set_ylabel('Precision')
ax2.set_title('Precision-Recall Curve')
ax2.legend(loc="lower left")

plt.tight_layout()
plt.show()
